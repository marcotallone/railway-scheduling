# %%
from railway import *

# # Constant values
# n = 30
# periods = 30
# jobs = 40
# passengers = 2000
# K = 3

# # Create blueprint model
# model = Railway(n, periods, jobs, passengers, K)

# # Generate problem parameters
# job_min_time, job_max_time = 1, 3
# job_min_length, job_max_length = 1, 3
# pause_min_time, pause_max_time = 0, 1
# min_demand, max_demand = 0.5, 0.9
# min_share, max_share = 0.5, 0.9
# min_capacity, max_capacity = 0.5, 0.7
# n_max_events = 0
# event_min_length, event_max_length = 0, 0

# model.generate(
#     job_min_time,
#     job_max_time,
#     job_min_length,
#     job_max_length,
#     pause_min_time,
#     pause_max_time,
#     min_demand,
#     max_demand,
#     min_share,
#     max_share,
#     min_capacity,
#     max_capacity,
#     n_max_events,
#     event_min_length,
#     event_max_length,
# )


# Load model

# Define problem parameters
N = 10
T = 50
J = 40
P = 2000
K = 3

# Name of the file to load
FILENAME = f"../datasets/railway_N{N}_T{T}_J{J}_P{P}_K{K}.json"

# Instantiate the Railway object
model = Railway.load(FILENAME)


# Set up the three models by (deep) copying the blueprint model
model0 = Railway.copy(model)
model1 = Railway.copy(model)
model2 = Railway.copy(model)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2629256
# Academic license - for non-commercial use only - expires 2026-02-27

# %%
# Model 0: "as-is" Gurobi model with no heuristics or cuts
print("\nModel 0\n")
# model0.model.setParam('OutputFlag', 0) # verbose
model0.model.setParam('TimeLimit', 30) # time limit
model0.model.setParam('LPWarmStart', 0)
model0.model.setParam('PoolSolutions', 1)
model0.model.setParam('Cuts', 0)
model0.model.setParam('Heuristics', 0)
model0.model.setParam('Symmetry', 0)
model0.model.setParam('Threads', 1)

model0.set_constraints()
model0.set_objective()

results0 = model0.optimize()
# print("Runtime:", results0['runtime'])
# print("Gap:", results0['mip_gap'])
# print("Objective value:", results0['obj_val'])
# Out:
# Model 0
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 39985 rows, 26500 columns and 116590 nonzeros
# Model fingerprint: 0x47748fd9
# Variable types: 7250 continuous, 19250 integer (19250 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 6e+06]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 6e+06]
# Presolve removed 28901 rows and 20045 columns
# Presolve time: 1.52s
# Presolved: 11084 rows, 6455 columns, 37026 nonzeros
# Variable types: 1874 continuous, 4581 integer (4581 binary)
#
# Root relaxation: objective -3.533952e+05, 4911 iterations, 0.11 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -353395.15    0 1117          - -353395.15      -     -    2s
#      0     0 -99119.068    0 1132          - -99119.068      -     -    5s
#      0     2 -99069.842    0 1132          - -99069.842      -     -    6s
#    546   548 -62809.807  504  785          - -97731.627      -   6.8   10s
# * 1012   979             846    5959.4953903 -97731.627  1740%   5.5   11s
#   1023   983 -24668.945   10  615 5959.49539 -24736.717   515%  16.7   15s
#   1151  1053 -8725.2082   74  389 5959.49539 -20595.717   446%  19.5   20s
# * 1554  1223             275    5293.2386101 -20595.717   489%  16.8   24s
# * 1556  1177             276    5293.1963566 -20595.717   489%  16.8   24s
# * 1558  1131             277    5289.3512880 -20595.717   489%  16.7   24s
# * 1560  1086             278    5287.6526972 -20595.717   490%  16.7   24s
# * 1581  1036             296    5286.1062191 -20595.717   490%  16.5   24s
#   1601  1030 5266.06961  316    6 5286.10622 -20595.717   490%  16.3   25s
#   1831  1077 -10442.270   13  318 5286.10622 -19952.341   477%  16.7   30s
#
# Explored 1832 nodes (40864 simplex iterations) in 30.01 seconds (11.08 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 5286.11
#
# Time limit reached
# Best objective 5.286105835260e+03, best bound -1.995234111345e+04, gap 477.4488%

# %%
# Model 1: model with simulated annealing heuristic
print("\nModel 1\n")
# model1.model.setParam('OutputFlag', 0) # verbos
model1.model.setParam('TimeLimit', 30) # time limit
model1.model.setParam('LPWarmStart', 0)
model1.model.setParam('PoolSolutions', 1)
model1.model.setParam('Cuts', 0)
model1.model.setParam('Heuristics', 0)
model1.model.setParam('Symmetry', 0)
model1.model.setParam('Threads', 1)

S = model1.simulated_annealing(T=5e5)
model1.set_solution(S)

model1.set_constraints()
model1.set_objective()

results1 = model1.optimize()
# print("Runtime:", results1['runtime'])
# print("Gap:", results1['mip_gap'])
# print("Objective value:", results1['obj_val'])
# Out:
# Model 1
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 39985 rows, 26500 columns and 116590 nonzeros
# Model fingerprint: 0x05637d79
# Variable types: 7250 continuous, 19250 integer (19250 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 6e+06]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 6e+06]
#
# User MIP start produced solution with objective 5856.94 (0.05s)
# Loaded user MIP start with objective 5856.94
#
# Presolve removed 28901 rows and 20045 columns
# Presolve time: 1.22s
# Presolved: 11084 rows, 6455 columns, 37026 nonzeros
# Found heuristic solution: objective 5841.2266848
# Variable types: 1874 continuous, 4581 integer (4581 binary)
#
# Root relaxation: objective -3.533952e+05, 4911 iterations, 0.09 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -353395.15    0 1117 5841.22668 -353395.15  6150%     -    2s
#      0     0 -99119.068    0 1132 5841.22668 -99119.068  1797%     -    4s
#      0     2 -99069.842    0 1132 5841.22668 -99069.842  1796%     -    4s
#     53    55 -96405.290   53 1120 5841.22668 -97393.147  1767%  34.5    5s
#    913   888 -88089.805  272 1132 5841.22668 -97371.378  1767%   7.3   10s
#    954   916 -21131.726   28  501 5841.22668 -21131.726   462%  21.3   15s
#   1233  1093 3625.46182  167   63 5841.22668 -20889.546   458%  21.2   20s
# * 1285  1079             193    5403.9942952 -20889.546   487%  20.6   20s
# * 1287  1035             194    5403.7492249 -20889.546   487%  20.6   20s
# * 1289   994             195    5402.0506342 -20889.546   487%  20.6   20s
# * 1309   947             212    5400.5041560 -20889.546   487%  20.3   20s
# * 1539  1004             135    5322.8942854 -20519.290   485%  21.1   24s
# * 1540   967             136    5321.5506241 -20519.290   486%  21.1   24s
# * 1543   934             137    5321.5252720 -20519.290   486%  21.1   24s
# * 1547   901             139    5321.2802017 -20519.290   486%  21.0   24s
# * 1549   871             140    5319.5816109 -20519.290   486%  21.0   24s
# * 1582   831             157    5318.0351328 -20519.290   486%  20.6   24s
#   1641   818 4042.19218   38  265 5318.03513 -20383.646   483%  20.2   25s
#
# Explored 2287 nodes (56050 simplex iterations) in 30.01 seconds (12.53 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 5318.03
#
# Time limit reached
# Best objective 5.318034747803e+03, best bound -1.995331335485e+04, gap 475.2009%

# %%
# Model 2: Full model plus valid inequalities and cutting planes
print("\nModel 2\n")
# model2.model.setParam('OutputFlag', 0) # verbose
model2.model.setParam('TimeLimit', 30) # time limit
model2.model.setParam('LPWarmStart', 0)
model2.model.setParam('PoolSolutions', 1)
model2.model.setParam('Cuts', 0)
model2.model.setParam('Heuristics', 0)
model2.model.setParam('Symmetry', 0)
model2.model.setParam('Threads', 1)

S = model2.simulated_annealing()
model2.set_solution(S)

model2.set_constraints()
model2.set_objective()

model2.set_valid_inequalities()
model2.set_cutting_planes()

results2 = model2.optimize()
# print("Runtime:", results2['runtime'])
# print("Gap:", results2['mip_gap'])
# print("Objective value:", results2['obj_val'])
# Out:
# Model 2
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Set parameter Presolve to value 1
# Set parameter Cuts to value 0
# Set parameter BQPCuts to value -1
# Set parameter CliqueCuts to value -1
# Set parameter CoverCuts to value -1
# Set parameter FlowCoverCuts to value -1
# Set parameter FlowPathCuts to value -1
# Set parameter GomoryPasses to value -1
# Set parameter GUBCoverCuts to value -1
# Set parameter ImpliedCuts to value -1
# Set parameter LiftProjectCuts to value -1
# Set parameter MIRCuts to value -1
# Set parameter ModKCuts to value -1
# Set parameter NetworkCuts to value -1
# Set parameter RelaxLiftCuts to value -1
# Set parameter StrongCGCuts to value -1
# Set parameter ZeroHalfCuts to value -1
# Set parameter CutPasses to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# CutPasses  0
# Presolve  1
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 44757 rows, 26500 columns and 124134 nonzeros
# Model fingerprint: 0x904b645a
# Variable types: 7250 continuous, 19250 integer (19250 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 6e+06]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 6e+06]
#
# User MIP start produced solution with objective 5372.96 (0.07s)
# Loaded user MIP start with objective 5372.96
#
# Presolve removed 33746 rows and 20005 columns
# Presolve time: 1.24s
# Presolved: 11011 rows, 6495 columns, 36531 nonzeros
# Found heuristic solution: objective 5355.2421575
# Variable types: 1874 continuous, 4621 integer (4619 binary)
#
# Root relaxation: objective -4.771127e+04, 5400 iterations, 0.15 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -47711.266    0  849 5355.24216 -47711.266   991%     -    1s
#      0     2 -47495.671    0  849 5355.24216 -47495.671   987%     -    2s
#    105   105 -25123.170  102  641 5355.24216 -41348.129   872%   9.0    5s
#    533   500 -3696.9156  237  553 5355.24216 -34562.536   745%   5.9   10s
#    654   571 -4015.6664   73  360 5355.24216 -33513.359   726%  29.4   15s
# *  692   568              92    5299.4277185 -33513.359   732%  29.9   16s
# *  694   545              93    5299.3094086 -33513.359   732%  29.8   16s
# *  696   521              94    5296.8080014 -33513.359   733%  29.8   16s
# *  698   497              95    5295.5911005 -33513.359   733%  29.7   16s
# *  710   473             106    5294.6784249 -33513.359   733%  29.2   16s
# *  715   453             110    5294.3150448 -33513.359   733%  29.1   16s
# *  719   432             113    5292.7685667 -33513.359   733%  28.9   16s
#   1098   415 -18873.197   58  475 5292.76857 -31923.861   703%  30.9   20s
#   1968   994 -17630.291   44  492 5292.76857 -30536.865   677%  22.7   25s
#
# Explored 3027 nodes (66066 simplex iterations) in 30.01 seconds (13.71 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 5292.77
#
# Time limit reached
# Best objective 5.292768190119e+03, best bound -2.730099769803e+04, gap 615.8170%
