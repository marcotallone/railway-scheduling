# %%
from railway import *

# Constant values
n = 30
periods = 30
jobs = 40
passengers = 2000
K = 3

# Create blueprint model
model = Railway(n, periods, jobs, passengers, K)

# Generate problem parameters
job_min_time, job_max_time = 1, 3
job_min_length, job_max_length = 1, 3
pause_min_time, pause_max_time = 0, 1
min_demand, max_demand = 0.5, 0.9
min_share, max_share = 0.5, 0.9
min_capacity, max_capacity = 0.5, 0.7
n_max_events = 0
event_min_length, event_max_length = 0, 0

model.generate(
    job_min_time,
    job_max_time,
    job_min_length,
    job_max_length,
    pause_min_time,
    pause_max_time,
    min_demand,
    max_demand,
    min_share,
    max_share,
    min_capacity,
    max_capacity,
    n_max_events,
    event_min_length,
    event_max_length,
)


# # Load model

# # Define problem parameters
# N = 10
# T = 50
# J = 40
# P = 2000
# K = 3

# # Name of the file to load
# FILENAME = f"../datasets/railway_N{N}_T{T}_J{J}_P{P}_K{K}.json"

# Instantiate the Railway object
# model = Railway.load(FILENAME)


# Set up the three models by (deep) copying the blueprint model
model0 = Railway.copy(model)
model1 = Railway.copy(model)
model2 = Railway.copy(model)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2629256
# Academic license - for non-commercial use only - expires 2026-02-27
# Problem generated successfully. Remember to set constraints and objective (again).

# %%
# Test model feasibility with a validator model
validate = Railway.copy(model)
validate.set_constraints()
validate.set_objective()
validresults = validate.optimize()

validresults
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 233425 rows, 135300 columns and 649278 nonzeros
# Model fingerprint: 0xfa17d88a
# Variable types: 40050 continuous, 95250 integer (95250 binary)
# Coefficient statistics:
#   Matrix range     [4e-02, 4e+07]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 4e+07]
# Presolve removed 212500 rows and 120835 columns
# Presolve time: 0.29s
# Presolved: 20925 rows, 14465 columns, 55882 nonzeros
# Variable types: 4620 continuous, 9845 integer (9845 binary)
# Performing another presolve...
# Presolve removed 15318 rows and 11184 columns
# Presolve time: 0.65s
# Found heuristic solution: objective 12412.255507
#
# Root relaxation: objective -5.853597e+04, 3010 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -58535.971    0  534 12412.2555 -58535.971   572%     -    1s
# H    0     0                    11207.194597 -58535.971   622%     -    1s
# H    0     0                    11198.183744 -58535.971   623%     -    1s
# H    0     0                    11122.127113 -58535.971   626%     -    1s
# H    0     0                    11113.116260 -58535.971   627%     -    1s
#      0     0 -31387.085    0  307 11113.1163 -31387.085   382%     -    1s
# H    0     0                    11022.863374 -31263.066   384%     -    1s
# H    0     0                    11021.912086 -31263.066   384%     -    1s
#      0     0 -28791.953    0  299 11021.9121 -28791.953   361%     -    1s
#      0     0 -13683.954    0  206 11021.9121 -13683.954   224%     -    1s
# H    0     0                    10956.960957 -13660.419   225%     -    1s
#      0     0 -2264.4099    0  159 10956.9610 -2264.4099   121%     -    1s
# H    0     0                    10923.215671 -2231.8586   120%     -    1s
#      0     0 -2231.8586    0  167 10923.2157 -2231.8586   120%     -    1s
# H    0     0                    10904.046551 -2231.8586   120%     -    1s
# H    0     0                    10904.046508 -2231.8586   120%     -    1s
# H    0     0                    10704.474625 7241.80102  32.3%     -    1s
# H    0     0                    10685.434543 7241.80102  32.2%     -    1s
# H    0     0                    10685.434532 7241.80102  32.2%     -    1s
#      0     0 7241.80102    0  117 10685.4345 7241.80102  32.2%     -    1s
# H    0     0                    10661.750543 7242.12545  32.1%     -    2s
# H    0     0                    10542.051321 7242.12545  31.3%     -    2s
#      0     0 8603.53178    0   79 10542.0513 8603.53178  18.4%     -    2s
#      0     0 8603.89281    0   19 10542.0513 8603.89281  18.4%     -    2s
#      0     0 10388.5778    0   12 10542.0513 10388.5778  1.46%     -    2s
# H    0     0                    10472.659878 10389.4228  0.79%     -    2s
# H    0     0                    10472.659861 10389.4228  0.79%     -    2s
#      0     0 10389.4228    0   12 10472.6599 10389.4228  0.79%     -    2s
# H    0     0                    10393.021301 10389.4228  0.03%     -    2s
# H    0     0                    10393.021298 10389.4228  0.03%     -    2s
#
# Cutting planes:
#   Learned: 8
#   Gomory: 53
#   Cover: 52
#   Implied bound: 118
#   Clique: 18
#   MIR: 361
#   StrongCG: 1
#   Mod-K: 1
#   RLT: 3
#   Relax-and-lift: 259
#
# Explored 1 nodes (5886 simplex iterations) in 2.33 seconds (1.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 10393 10393 10472.7 ... 10957
# No other solutions better than 10393
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.039301635823e+04, best bound 1.039301635823e+04, gap 0.0000%
# {'runtime': 2.339933156967163,
#  'nodes': 1.0,
#  'iterations': 5886.0,
#  'gap': 0.0,
#  'obj': 10393.016358233988}

# %%
# Model 0: "as-is" Gurobi model with no heuristics or cuts
print("\nModel 0\n")
# model0.model.setParam('OutputFlag', 0) # verbose
model0.model.setParam('TimeLimit', 30) # time limit
model0.model.setParam('LPWarmStart', 0)
model0.model.setParam('PoolSolutions', 1)
model0.model.setParam('Cuts', 0)
model0.model.setParam('CutPasses', 0)
model0.model.setParam('Heuristics', 0)
model0.model.setParam('Symmetry', 0)
model0.model.setParam('Threads', 1)
model0.model.setParam('Presolve', 1)

model0.set_constraints()
model0.set_objective()

results0 = model0.optimize()
# print("Runtime:", results0['runtime'])
# print("Gap:", results0['mip_gap'])
# print("Objective value:", results0['obj_val'])
# Out:
# Model 0
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter CutPasses to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Set parameter Presolve to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# CutPasses  0
# Presolve  1
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 233425 rows, 135300 columns and 649278 nonzeros
# Model fingerprint: 0xfa17d88a
# Variable types: 40050 continuous, 95250 integer (95250 binary)
# Coefficient statistics:
#   Matrix range     [4e-02, 4e+07]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 4e+07]
# Presolve removed 212500 rows and 120835 columns
# Presolve time: 0.29s
# Presolved: 20925 rows, 14465 columns, 55882 nonzeros
# Variable types: 4620 continuous, 9845 integer (9845 binary)
# Performing another presolve...
# Presolve removed 15302 rows and 11238 columns
# Presolve time: 0.51s
#
# Root relaxation: objective -9.475469e+04, 2104 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -94754.695    0  223          - -94754.695      -     -    0s
#      0     2 -94527.717    0  223          - -94527.717      -     -    0s
# *  184   160             147    10977.620486 -92656.745   944%  11.3    1s
# *  186   158             146    10969.655165 -92656.745   945%  11.2    1s
# *  643   486              49    10800.111252 -20675.560   291%  14.4    3s
# *  645   459              49    10717.212871 -20675.560   293%  14.3    3s
# *  754   457              41    10700.681224 -18899.829   277%  14.5    3s
# *  759   436              43    10690.341174 -18899.829   277%  14.5    3s
# *  761   414              43    10686.762150 -18899.829   277%  14.4    3s
# *  906   415              40    10663.796216 -17606.369   265%  14.5    4s
#   1233   522 6575.11581   33   14 10663.7962 -16805.376   258%  14.8    5s
# * 1369   554              59    10467.787089 -16534.329   258%  14.8    5s
# * 2245  1098              60    10467.130601 -14325.802   237%  14.0    6s
# * 2252  1097              61    10440.631654 -14325.802   237%  14.0    6s
#   4064  2248 -3351.7820   33  138 10440.6317 -11833.184   213%  13.6   10s
# * 4371  2449              66    10438.189339 -11639.748   212%  13.5   10s
# * 4373  2448              66    10437.809232 -11639.748   212%  13.5   10s
# * 4592  2595              70    10437.083980 -11484.597   210%  13.4   10s
#   7391  4373 -10204.179   31  161 10437.0840 -10481.043   200%  12.7   15s
# * 8636  5089              60    10425.793265 -10151.541   197%  12.9   17s
# * 8637  5088              60    10425.413159 -10151.541   197%  12.9   17s
#   9644  5677 3376.16639   28   41 10425.4132 -9846.3842   194%  13.0   20s
#  12210  7175 8270.41715   39    8 10425.4132 -8980.3108   186%  13.1   25s
#
# Explored 14582 nodes (194005 simplex iterations) in 30.03 seconds (29.05 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10425.4
#
# Time limit reached
# Best objective 1.042540718047e+04, best bound -8.511175317189e+03, gap 181.6388%

# %%
results0
# Out:
# {'runtime': 30.033111095428467,
#  'nodes': 14582.0,
#  'iterations': 194005.0,
#  'gap': 1.8163878081554907,
#  'obj': 10425.407180465758}

# %%
# Model 1: model with simulated annealing heuristic
print("\nModel 1\n")
# model1.model.setParam('OutputFlag', 0) # verbos
model1.model.setParam('TimeLimit', 30) # time limit
model1.model.setParam('LPWarmStart', 0)
model1.model.setParam('PoolSolutions', 1)
model1.model.setParam('Cuts', 0)
model1.model.setParam('Heuristics', 0)
model1.model.setParam('Symmetry', 0)
model1.model.setParam('Threads', 1)

S, _ = model1.simulated_annealing(T=5e5, max_time = 30)
model1.set_solution(S)

model1.set_constraints()
model1.set_objective()

results1 = model1.optimize()
# print("Runtime:", results1['runtime'])
# print("Gap:", results1['mip_gap'])
# print("Objective value:", results1['obj_val'])
# Out:
# Model 1
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Constraint (5) is not satisfied.
# Constraint (7) is not satisfied.
# Constraint (7) is not satisfied.
# Constraint (5) is not satisfied.
# Constraint (7) is not satisfied.
# Constraint (5) is not satisfied.
# Constraint (7) is not satisfied.
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 233425 rows, 135300 columns and 649278 nonzeros
# Model fingerprint: 0xa86a6982
# Variable types: 40050 continuous, 95250 integer (95250 binary)
# Coefficient statistics:
#   Matrix range     [4e-02, 4e+07]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 4e+07]
#
# User MIP start produced solution with objective 12637.9 (0.14s)
# Loaded user MIP start with objective 12637.9
#
# Presolve removed 212500 rows and 120835 columns
# Presolve time: 0.31s
# Presolved: 20925 rows, 14465 columns, 55882 nonzeros
# Variable types: 4620 continuous, 9845 integer (9845 binary)
# Performing another presolve...
# Presolve removed 15337 rows and 11238 columns
# Presolve time: 0.54s
# Found heuristic solution: objective 11983.475964
#
# Root relaxation: objective -9.475469e+04, 2025 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -94754.695    0  223 11983.4760 -94754.695   891%     -    1s
#      0     0 -35566.181    0  443 11983.4760 -35566.181   397%     -    1s
#      0     2 -35440.454    0  443 11983.4760 -35440.454   396%     -    1s
# *  204   197             138    10902.441733 -34757.292   419%  12.1    1s
# *  205   196             138    10856.558209 -34757.292   420%  12.1    1s
# *  378   347             135    10815.231931 -34669.280   421%  10.5    1s
# *  573   448              20    10417.196553 10260.3938  1.51%  12.7    3s
# *  578   419              19    10416.471662 10260.3938  1.50%  12.6    3s
# *  591   402              20    10404.837748 10274.6450  1.25%  12.5    3s
# *  594   376              22    10404.062865 10274.6450  1.24%  12.5    3s
# *  601   358              18    10394.039678 10298.1887  0.92%  12.3    3s
# *  604   336              19    10393.989647 10298.1887  0.92%  12.3    3s
# *  605   316              19    10393.264395 10298.1887  0.91%  12.3    3s
# *  620   295              21    10392.704999 10329.2464  0.61%  12.2    3s
# *  625   277              23    10391.929716 10329.2464  0.60%  12.2    3s
#
# Explored 633 nodes (10909 simplex iterations) in 3.52 seconds (2.66 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 10391.9
# No other solutions better than 10391.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.039192464612e+04, best bound 1.039192464612e+04, gap 0.0000%

# %%
# Model 2: Full model plus valid inequalities and cutting planes
print("\nModel 2\n")
# model2.model.setParam('OutputFlag', 0) # verbose
model2.model.setParam('TimeLimit', 30) # time limit
model2.model.setParam('LPWarmStart', 0)
model2.model.setParam('PoolSolutions', 1)
model2.model.setParam('Cuts', 0)
model2.model.setParam('Heuristics', 0)
model2.model.setParam('Symmetry', 0)
model2.model.setParam('Threads', 1)

# S, _ = model2.simulated_annealing()
model2.set_solution(S)

model2.set_constraints()
model2.set_objective()

model2.set_valid_inequalities()
model2.set_cutting_planes()

results2 = model2.optimize()
# print("Runtime:", results2['runtime'])
# print("Gap:", results2['mip_gap'])
# print("Objective value:", results2['obj_val'])
# Out:
# Model 2
#
# Set parameter TimeLimit to value 30
# Set parameter LPWarmStart to value 0
# Set parameter PoolSolutions to value 1
# Set parameter Cuts to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Set parameter Threads to value 1
# Set parameter Cuts to value 0
# Set parameter BQPCuts to value -1
# Set parameter CliqueCuts to value -1
# Set parameter CoverCuts to value -1
# Set parameter FlowCoverCuts to value -1
# Set parameter FlowPathCuts to value -1
# Set parameter GomoryPasses to value -1
# Set parameter GUBCoverCuts to value -1
# Set parameter ImpliedCuts to value -1
# Set parameter LiftProjectCuts to value -1
# Set parameter MIRCuts to value -1
# Set parameter ModKCuts to value -1
# Set parameter NetworkCuts to value -1
# Set parameter RelaxLiftCuts to value -1
# Set parameter StrongCGCuts to value -1
# Set parameter ZeroHalfCuts to value -1
# Set parameter CutPasses to value 0
# Set parameter Heuristics to value 0
# Set parameter Symmetry to value 0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 1 threads
#
# Non-default parameters:
# TimeLimit  30
# LPWarmStart  0
# Heuristics  0
# Symmetry  0
# Cuts  0
# CutPasses  0
# Threads  1
# PoolSolutions  1
#
# Optimize a model with 44757 rows, 26500 columns and 124134 nonzeros
# Model fingerprint: 0x5af07b9a
# Variable types: 7250 continuous, 19250 integer (19250 binary)
# Coefficient statistics:
#   Matrix range     [3e-02, 6e+06]
#   Objective range  [1e+03, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 6e+06]
#
# User MIP start produced solution with objective 5386.63 (0.04s)
# Loaded user MIP start with objective 5386.63
#
# Presolve removed 33673 rows and 20045 columns
# Presolve time: 1.13s
# Presolved: 11084 rows, 6455 columns, 37026 nonzeros
# Found heuristic solution: objective 5381.3503181
# Variable types: 1874 continuous, 4581 integer (4581 binary)
#
# Root relaxation: objective -3.409442e+05, 4842 iterations, 0.08 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -340944.20    0 1103 5381.35032 -340944.20  6436%     -    1s
#      0     2 -340788.44    0 1103 5381.35032 -340788.44  6433%     -    2s
#    132   134 -246344.50  132  812 5381.35032 -340346.61  6425%  14.5    5s
#    564   558 -39761.176  556  189 5381.35032 -340346.61  6425%   8.4   10s
#    955   937 -55698.231   15  720 5381.35032 -55698.231  1135%  15.1   15s
#   1054   943 -22478.804   64  200 5381.35032 -54611.510  1115%  20.4   20s
# * 1170   869              40    5347.9644477 -54404.561  1117%  22.2   22s
# * 1172   822              41    5347.1362790 -54404.561  1117%  22.1   22s
# * 1175   780              43    5347.1109269 -54404.561  1117%  22.1   22s
# * 1177   740              44    5346.8658566 -54404.561  1118%  22.0   22s
# * 1179   701              45    5345.5898009 -54404.561  1118%  22.0   22s
# * 1193   659              57    5345.1672659 -54404.561  1118%  21.8   22s
# * 1203   621              65    5344.3729001 -54404.561  1118%  21.6   22s
# * 1206   588              67    5343.6207877 -54404.561  1118%  21.6   22s
#   1386   532     cutoff   27      5343.62079 -46938.359   978%  24.3   25s
#   1853   471  postponed   56      5343.62079 -46643.575   973%  27.0   30s
#
# Explored 1854 nodes (56096 simplex iterations) in 30.01 seconds (17.11 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 5343.62
#
# Time limit reached
# Best objective 5.343620404727e+03, best bound -4.664357476900e+04, gap 972.8834%

# %%
# Summary
print("\nModel0\n")
print("Runtime:", results0['runtime'])
print("Gap:", results0['gap'])
print("Objective value:", results0['obj'])
# Out:
# Model0
#
# Runtime: 30.015144109725952
# Gap: 4.4573652422653165
# Objective value: 5286.105835259892

# %%
print("\nModel1\n")
print("Runtime:", results1['runtime'])
print("Gap:", results1['mip_gap'])
print("Objective value:", results1['obj_val'])

print("\nModel2\n")
print("Runtime:", results2['runtime'])
print("Gap:", results2['mip_gap'])
print("Objective value:", results2['obj_val'])

# %%
model0.model.ObjVal
# Out:
# 5286.105835259892

# %%
model.model.ObjVal
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.model.ObjVal
#
# File src/gurobipy/_model.pyx:393, in gurobipy._model.Model.__getattr__()
#
# File src/gurobipy/_model.pyx:2121, in gurobipy._model.Model.getAttr()
#
# File src/gurobipy/_attrutil.pyx:117, in gurobipy._attrutil._getattr()
#
# AttributeError: Unable to retrieve attribute 'ObjVal'
